# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml

# %%
import os
import nltk
import nltk.corpus

# %%
print(os.listdir(nltk.data.find("corpora")))
# Out:
# [u'abc', u'abc.zip', u'alpino', u'alpino.zip', u'biocreative_ppi', u'biocreative_ppi.zip', u'brown', u'brown.zip', u'brown_tei', u'brown_tei.zip', u'cess_cat', u'cess_cat.zip', u'cess_esp', u'cess_esp.zip', u'chat80', u'chat80.zip', u'city_database', u'city_database.zip', u'cmudict', u'cmudict.zip', u'comparative_sentences', u'comparative_sentences.zip', u'comtrans.zip', u'conll2000', u'conll2000.zip', u'conll2002', u'conll2002.zip', u'conll2007.zip', u'crubadan', u'crubadan.zip', u'dependency_treebank', u'dependency_treebank.zip', u'dolch', u'dolch.zip', u'europarl_raw', u'europarl_raw.zip', u'floresta', u'floresta.zip', u'framenet_v15', u'framenet_v15.zip', u'framenet_v17', u'framenet_v17.zip', u'gazetteers', u'gazetteers.zip', u'genesis', u'genesis.zip', u'gutenberg', u'gutenberg.zip', u'ieer', u'ieer.zip', u'inaugural', u'inaugural.zip', u'indian', u'indian.zip', u'jeita.zip', u'kimmo', u'kimmo.zip', u'knbc.zip', u'lin_thesaurus', u'lin_thesaurus.zip', u'machado.zip', u'mac_morph
# ...

# %%
nltk.corpus.gutenberg.fileids()
# Out:
# [u'austen-emma.txt',
#  u'austen-persuasion.txt',
#  u'austen-sense.txt',
#  u'bible-kjv.txt',
#  u'blake-poems.txt',
#  u'bryant-stories.txt',
#  u'burgess-busterbrown.txt',
#  u'carroll-alice.txt',
#  u'chesterton-ball.txt',
#  u'chesterton-brown.txt',
#  u'chesterton-thursday.txt',
#  u'edgeworth-parents.txt',
#  u'melville-moby_dick.txt',
#  u'milton-paradise.txt',
#  u'shakespeare-caesar.txt',
#  u'shakespeare-hamlet.txt',
#  u'shakespeare-macbeth.txt',
#  u'whitman-leaves.txt']

# %%
hamlet =nltk.corpus.gutenberg.words("shakespeare-hamlet.txt")
hamlet
# Out:
# [u'[', u'The', u'Tragedie', u'of', u'Hamlet', u'by', ...]

# %%
for words in hamlet[:500]:
    print words
# Out:
# [
# The
# Tragedie
# of
# Hamlet
# by
# William
# Shakespeare
# 1599
# ]
# Actus
# Primus
# .
# Scoena
# Prima
# .
# Enter
# Barnardo
# and
# Francisco
# two
# Centinels
# .
# Barnardo
# .
# Who
# '
# s
# there
# ?
# Fran
# .
# Nay
# answer
# me
# :
# Stand
# &
# vnfold
# your
# selfe
# Bar
# .
# Long
# liue
# the
# King
# Fran
# .
# Barnardo
# ?
# Bar
# .
# He
# Fran
# .
# You
# come
# most
# carefully
# vpon
# your
# houre
# Bar
# .
# '
# Tis
# now
# strook
# twelue
# ,
# get
# thee
# to
# bed
# Francisco
# Fran
# .
# For
# this
# releefe
# much
# thankes
# :
# '
# Tis
# bitter
# cold
# ,
# And
# I
# am
# sicke
# at
# heart
# Barn
# .
# Haue
# you
# had
# quiet
# Guard
# ?
# Fran
# .
# Not
# a
# Mouse
# stirring
# Barn
# .
# Well
# ,
# goodnight
# .
# If
# you
# do
# meet
# Horatio
# and
# Marcellus
# ,
# the
# Riuals
# of
# my
# Watch
# ,
# bid
# them
# make
# hast
# .
# Enter
# Horatio
# and
# Marcellus
# .
# Fran
# .
# I
# thinke
# I
# heare
# them
# .
# Stand
# :
# who
# '
# s
# ...

# %%
AI="""According to the father of Artificial Intelligence, John McCarthy, it is The science and engineering of making Artificial intelligence is a way

of making a computer-controlled robot, or a software think intelligently, in the simulation of AI is accomplished by studying how

human brain thinks, and how humans learn, decide, and work while trying to solve a problem, while exploting the power of the computer systems,

the cuiosity of human, lead him to wonder, "Can a machine think and behave development of AI started with the intention of creating similar intelligence 

in machines that we find and regard high To create Expert Systems - The systems which exhibit intelligent behaviour", learn, demonstrate, explain,

and advice its users. To Implement Human Intelligence in Machine - Creating system thath understand, think, learn and behave like humans. 

Artificial intelligence is a science and technology based on discipilines such a Computer Science, Biology, Psychology, Linguistion, out of the following areas, one or multiple areas can contribute to build an intelligent system. """

# %%
type(AI)
# Out:
# str

# %%
from nltk.tokenize import word_tokenize

# %%
AI_tokens =word_tokenize(AI)
AI_tokens
# Out:
# ['According',
#  'to',
#  'the',
#  'father',
#  'of',
#  'Artificial',
#  'Intelligence',
#  ',',
#  'John',
#  'McCarthy',
#  ',',
#  'it',
#  'is',
#  'The',
#  'science',
#  'and',
#  'engineering',
#  'of',
#  'making',
#  'Artificial',
#  'intelligence',
#  'is',
#  'a',
#  'way',
#  'of',
#  'making',
#  'a',
#  'computer-controlled',
#  'robot',
#  ',',
#  'or',
#  'a',
#  'software',
#  'think',
#  'intelligently',
#  ',',
#  'in',
#  'the',
#  'simulation',
#  'of',
#  'AI',
#  'is',
#  'accomplished',
#  'by',
#  'studying',
#  'how',
#  'human',
#  'brain',
#  'thinks',
#  ',',
#  'and',
#  'how',
#  'humans',
#  'learn',
#  ',',
#  'decide',
#  ',',
#  'and',
#  'work',
#  'while',
#  'trying',
#  'to',
#  'solve',
#  'a',
#  'problem',
#  ',',
#  'while',
#  'exploting',
#  'the',
#  'power',
#  'of',
#  'the',
#  'computer',
#  'systems',
#  ',',
#  'the',
#  'cuiosity',
#  'of',
#  'human',
#  ',',
#  'lead',
#  'him',
#  'to',
#  'wonder',
#  ',',
#  '``',
#  'Can',
# ...

# %%
len(AI)
# Out:
# 1093

# %%
from nltk.probability import FreqDist
fdist = FreqDist()

# %%
for word in AI_tokens:
    fdist[word.upper()]+=1
fdist
# Out:
# FreqDist({',': 22, 'THE': 9, 'OF': 9, 'AND': 8, 'A': 7, 'TO': 6, 'INTELLIGENCE': 5, 'IS': 4, 'HUMAN': 3, 'SCIENCE': 3, ...})

# %%
fdist_top10 = fdist.most_common(15)
fdist_top10
# Out:
# [(',', 22),
#  ('THE', 9),
#  ('OF', 9),
#  ('AND', 8),
#  ('A', 7),
#  ('TO', 6),
#  ('INTELLIGENCE', 5),
#  ('IS', 4),
#  ('HUMAN', 3),
#  ('SCIENCE', 3),
#  ('THINK', 3),
#  ('SYSTEMS', 3),
#  ('ARTIFICIAL', 3),
#  ('.', 3),
#  ('LEARN', 3)]

# %%
from nltk.tokenize import blankline_tokenize
AI_blank = blankline_tokenize(AI)
len(AI_blank)
# Out:
# 7

# %%
from nltk.util import bigrams, trigrams, ngrams

# %%
string = "The best and most beautiful things in the workd cannot be seen or even touched, they must be felt with the heart"
quotes_tokens = nltk.word_tokenize(string)
quotes_token
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-0d77c5faf14f> in <module>()
#       1 string = "The best and most beautiful things in the workd cannot be seen or even touched, they must be felt with the heart"
#       2 quotes_tokens = nltk.word_tokenize(string)
# ----> 3 quotes_token
#
# NameError: name 'quotes_token' is not defined
